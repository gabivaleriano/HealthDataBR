# %%
import pandas as pd
from healthData_functions import *

warnings.filterwarnings("ignore")

# %% [markdown]
# This notebook explore features distribution of in a dataset curated for predicting mortality among patients hospitalized with Chikungunya disease. Additionally, it presents the initial predictive performance of various machine learning models performing this task.
#
# More information: https://github.com/gabivaleriano/HealthDataBR

# %% [markdown]
# # Data visualization

# %%
data = pd.read_csv('chikungunya_death_22.csv')
data_test = pd.read_csv(r'/home/gabi/Documents/Chikungunya/chikungunya_death_20.csv')
visualization(data, 'Survivors', 'Dead')
# Out:
# Dataset size: 1611 rows, 20 columns
#
# Distribution of the target feature:
# death
# 0    0.972688
# 1    0.027312
# Name: proportion, dtype: float64

# %% [markdown]
# # Evaluating ML predictive performance

# %%
evaluate(data, data_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_61542">
#   <caption>Average performance and stdev among 5-fold cross-validation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61542_level0_col0" class="col_heading level0 col0" >svc_linear</th>
#       <th id="T_61542_level0_col1" class="col_heading level0 col1" >svc_rbf</th>
#       <th id="T_61542_level0_col2" class="col_heading level0 col2" >random_forest</th>
#       <th id="T_61542_level0_col3" class="col_heading level0 col3" >gradient_boosting</th>
#       <th id="T_61542_level0_col4" class="col_heading level0 col4" >logistic_regression</th>
#       <th id="T_61542_level0_col5" class="col_heading level0 col5" >bagging</th>
#       <th id="T_61542_level0_col6" class="col_heading level0 col6" >mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61542_level0_row0" class="row_heading level0 row0" >auc (mean)</th>
# ...

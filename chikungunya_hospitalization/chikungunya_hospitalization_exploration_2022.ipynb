# %%
import pandas as pd
from healthData_functions import *

warnings.filterwarnings("ignore")
# Out:
# /home/gabi/env1/lib/python3.11/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/gabi/env1/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/gabi/env1/lib/python3.11/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/gabi/env1/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %% [markdown]
# This notebook explore features distribution of a dataset curated for predicting hospitalization among patients with Chikungunya disease. Additionally, it presents the initial predictive performance of various machine learning models performing this task.
#
# For comprehensive details about these datasets, including information about data collection methods, sources, and a dictionary of variables, please refer to the project repository on GitHub:https://github.com/gabivaleriano/HealthDataBR.

# %% [markdown]
# # Data visualization

# %%
data = pd.read_csv('chikungunya_hospitalization_dataset_2022.csv')
data_test = pd.read_csv('chikungunya_hospitalization_dataset_2020.csv')
visualization(data, 'Non-hospitalized', 'Hospitalized')
# Out:
# Dataset size: 91788 rows, 24 columns
#
# Distribution of the target feature:
# 0    0.974256
# 1    0.025744
# Name: hospitalization, dtype: float64

# %% [markdown]
# # Evaluating ML predictive performance

# %%
evaluate(data, data_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a6ce">
#   <caption>Average performance and stdev among 5-fold cross-validation</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a6ce_level0_col0" class="col_heading level0 col0" >svc_linear</th>
#       <th id="T_6a6ce_level0_col1" class="col_heading level0 col1" >svc_rbf</th>
#       <th id="T_6a6ce_level0_col2" class="col_heading level0 col2" >random_forest</th>
#       <th id="T_6a6ce_level0_col3" class="col_heading level0 col3" >gradient_boosting</th>
#       <th id="T_6a6ce_level0_col4" class="col_heading level0 col4" >logistic_regression</th>
#       <th id="T_6a6ce_level0_col5" class="col_heading level0 col5" >bagging</th>
#       <th id="T_6a6ce_level0_col6" class="col_heading level0 col6" >mlp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a6ce_level0_row0" class="row_heading level0 row0" >auc (mean)</th>
# ...
